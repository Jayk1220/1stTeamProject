# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

# %%
#자동차 산업
    #창 열기
driver = webdriver.Chrome()
driver.get('https://www.yna.co.kr/industry/automobile')
driver.implicitly_wait(0.5)
    
    #기사 제목과 link 수집
car_articles = []

for page in range(1, 21):
#     print(f"페이지 수집 중: {page}")

    # 현재 URL 기준으로 page 파라미터만 변경
    url = f"{driver.current_url.split('?')[0]}?page={page}"
    driver.get(url)

    time.sleep(1)

    lis = driver.find_elements(By.CSS_SELECTOR, "li[data-cid]")

    for li in lis:
        try:
            a = li.find_element(By.CSS_SELECTOR, "strong.tit-wrap a.tit-news")
            title = a.find_element(By.CSS_SELECTOR, "span.title01").text.strip()
            link = a.get_attribute("href")
            date = li.find_element(By.CSS_SELECTOR, "span.txt-time").text.strip()

            car_articles.append({
                "date": date,
                "title": title,
                "url": link
            })

        except Exception:
            continue

def clean_text(s: str) -> str:
    return " ".join((s or "").split())

def extract_yna_body(driver):
    root = driver.find_element(By.CSS_SELECTOR, "div.story-news.article")

    # 본문은 p들로 구성되어 있으니 p만 모아서 합침
    ps = root.find_elements(By.CSS_SELECTOR, "p")

    chunks = []
    for p in ps:
        txt = clean_text(p.text)
        if not txt:
            continue

        # 저작권/제보/AI학습금지 같은 문구 제거
        if "무단 전재" in txt or "AI 학습" in txt or txt.startswith("제보는"):
            continue

        chunks.append(txt)

    return "\n".join(chunks).strip()

# 상세 본문 수집
for i, item in enumerate(car_articles, start=1):
    driver.get(item["url"])
    time.sleep(0.8)

    try:
        item["article"] = extract_yna_body(driver)
#         print(f"[본문] {i}/{len(articles)} OK")
    except Exception as e:
        item["article"] = ""
        print(f"[본문] {i}/{len(car_articles)} FAIL - {e}")

print("본문까지 완료. 예시 1개:")
print(car_articles[0]["title"])
print(car_articles[0]["article"][:300])
# Out:
# 본문까지 완료. 예시 1개:
# 현대차 국내사업본부장 교체…신임 본부장에 윤효준 전무
# [현대차그룹 제공. DB 및 재판매 금지]
# (서울=연합뉴스) 홍규빈 기자 = 현대자동차가 19일 윤효준 상무를 전무로 승진시키고 국내사업본부장으로 임명했다.
# 윤 신임 본부장은 국내 판매, 마케팅, 인사 등 다양한 분야에서 경험을 쌓았고 직전에는 국내지원사업부장을 맡아 국내 시장 판매 확대와 경쟁력 강화를 위한 인력·인프라 지원을 총괄했다.
# 전임자인 김승찬 전무는 이달 초 정유석 부사장의 뒤를 이어 국내사업본부장으로 내정됐으나 최근 일신상의 이유로 사의를 표한 것으로 전해졌다.
# 현대차는 윤 본부장의 풍부한 경험과 전문성을 바탕으로 국

# %%
#건설 산업
driver = webdriver.Chrome()
driver.get('https://www.yna.co.kr/industry/construction')
driver.implicitly_wait(0.5)

    #기사 제목과 link 수집
construct_articles = []

for page in range(1, 21):
#     print(f"페이지 수집 중: {page}")

    # 현재 URL 기준으로 page 파라미터만 변경
    url = f"{driver.current_url.split('?')[0]}?page={page}"
    driver.get(url)

    time.sleep(1)

    lis = driver.find_elements(By.CSS_SELECTOR, "li[data-cid]")

    for li in lis:
        try:
            a = li.find_element(By.CSS_SELECTOR, "strong.tit-wrap a.tit-news")
            title = a.find_element(By.CSS_SELECTOR, "span.title01").text.strip()
            link = a.get_attribute("href")
            date = li.find_element(By.CSS_SELECTOR, "span.txt-time").text.strip()

            construct_articles.append({
                "date": date,
                "title": title,
                "url": link
            })

        except Exception:
            continue

def clean_text(s: str) -> str:
    return " ".join((s or "").split())

def extract_yna_body(driver):
    root = driver.find_element(By.CSS_SELECTOR, "div.story-news.article")

    # 본문은 p들로 구성되어 있으니 p만 모아서 합침
    ps = root.find_elements(By.CSS_SELECTOR, "p")

    chunks = []
    for p in ps:
        txt = clean_text(p.text)
        if not txt:
            continue

        # 저작권/제보/AI학습금지 같은 문구 제거
        if "무단 전재" in txt or "AI 학습" in txt or txt.startswith("제보는"):
            continue

        chunks.append(txt)

    return "\n".join(chunks).strip()

# 상세 본문 수집
for i, item in enumerate(construct_articles, start=1):
    driver.get(item["url"])
    time.sleep(0.8)

    try:
        item["article"] = extract_yna_body(driver)
#         print(f"[본문] {i}/{len(articles)} OK")
    except Exception as e:
        item["article"] = ""
        print(f"[본문] {i}/{len(construct_articles)} FAIL - {e}")

print("본문까지 완료. 예시 1개:")
print(construct_articles[0]["title"])
print(construct_articles[0]["article"][:300])
# Out:
# 본문까지 완료. 예시 1개:
# 가평군, 2030년까지 읍내리에 임대주택 짓고 낡은 집 정비
# (가평=연합뉴스) 김도윤 기자 = 경기 가평군은 내년부터 2030년까지 가평읍 읍내리 일대에서 노후 주거환경 개선 사업을 추진한다고 19일 밝혔다.
# 국토교통부 '노후 주거지 정비 사업' 공모에 선정돼 국비를 지원받는다.
# 이 사업은 읍내리 5만㎡를 대상으로 추진되며 공공임대주택 건설, 노후주택 개량, 기반 시설 확충 등에 총 276억원이 투입된다.
# [가평군 제공. 재판매 및 DB 금지]
# 이 기간 가평군은 안전 D등급 빌라 등 낡은 공동주택을 철거하고 공공임대주택 64가구를 건설한다.
# 개별 노후주택 수리를 지원하고 맹지 해소 등 불합리

# %%
#헬스케어 산업
driver = webdriver.Chrome()
driver.get('https://www.yna.co.kr/industry/bioindustry-health')
driver.implicitly_wait(0.5)
    
    #기사 제목과 link 수집
health_articles = []

for page in range(1, 21):
#     print(f"페이지 수집 중: {page}")

    # 현재 URL 기준으로 page 파라미터만 변경
    url = f"{driver.current_url.split('?')[0]}?page={page}"
    driver.get(url)

    time.sleep(1)

    lis = driver.find_elements(By.CSS_SELECTOR, "li[data-cid]")

    for li in lis:
        try:
            a = li.find_element(By.CSS_SELECTOR, "strong.tit-wrap a.tit-news")
            title = a.find_element(By.CSS_SELECTOR, "span.title01").text.strip()
            link = a.get_attribute("href")
            date = li.find_element(By.CSS_SELECTOR, "span.txt-time").text.strip()

            health_articles.append({
                "date": date,
                "title": title,
                "url": link
            })

        except Exception:
            continue

def clean_text(s: str) -> str:
    return " ".join((s or "").split())

def extract_yna_body(driver):
    root = driver.find_element(By.CSS_SELECTOR, "div.story-news.article")

    # 본문은 p들로 구성되어 있으니 p만 모아서 합침
    ps = root.find_elements(By.CSS_SELECTOR, "p")

    chunks = []
    for p in ps:
        txt = clean_text(p.text)
        if not txt:
            continue

        # 저작권/제보/AI학습금지 같은 문구 제거
        if "무단 전재" in txt or "AI 학습" in txt or txt.startswith("제보는"):
            continue

        chunks.append(txt)

    return "\n".join(chunks).strip()

# 상세 본문 수집
for i, item in enumerate(health_articles, start=1):
    driver.get(item["url"])
    time.sleep(0.8)

    try:
        item["article"] = extract_yna_body(driver)
#         print(f"[본문] {i}/{len(articles)} OK")
    except Exception as e:
        item["article"] = ""
        print(f"[본문] {i}/{len(health_articles)} FAIL - {e}")

print("본문까지 완료. 예시 1개:")
print(health_articles[0]["title"])
print(health_articles[0]["article"][:300])
# Out:
# 본문까지 완료. 예시 1개:
# 식약처, 희귀 난소암 치료제 '엘라히어주' 허가
# [식품의약품안전처 제공]
# (서울=연합뉴스) 최현석 기자 = 식품의약품안전처는 19일 수입 희귀의약품 '엘라히어주(미르베툭시맙소라브탄신)'를 허가했다고 밝혔다.
# 엘라히어주는 난소암에서 고도로 발현되는 세포 표면 단백질의 일종인 '엽산 수용체 알파(FRα)'를 표적으로 하는 항체에 항암약물(세포독성 항암제)을 접합한 항체-약물 접합체(ADC)이다.
# 식약처는 고등급 장액성 상피성 난소암 환자의 치료 기회가 확대될 것으로 기대했다. 이 암은 난소암 중 가장 흔한 유형으로 난소 표면 상피세포에서 발생하며, 세포 모양이 불규칙하고 악성도가 높

# %%
df_car = pd.DataFrame(car_articles)

df_car.to_csv(
    "yna_automobile_articles.csv",
    index=False)

# %%
df_const = pd.DataFrame(construct_articles)

df_const.to_csv(
    "yna_construct_articles.csv",
    index=False)

# %%
df_health = pd.DataFrame(health_articles)

df_health.to_csv(
    "yna_health_articles.csv",
    index=False)

# %%
df_car.head()
# Out:
#           date                                        title  \
# 0  12-19 16:06                현대차 국내사업본부장 교체…신임 본부장에 윤효준 전무
# 1  12-19 14:33                  오산 옹벽 붕괴 사고 조사 기간 2개월 추가 연장
# 2  12-19 11:44  [K-VIBE] 정광복의 K-자율주행 도전기…도로 위 新 생태계를 주목하라-②
# 3  12-19 10:31              교통안전공단, 김제에 전국 첫 특장차 검사 지원센터 열어
# 4  12-19 10:07       한국타이어 대전공장, 친환경 소재 국제인증 'ISCC PLUS' 획득
#
#                                                  url  \
# 0  https://www.yna.co.kr/view/AKR2025121912280000...
# 1  https://www.yna.co.kr/view/AKR2025121909860000...
# 2  https://www.yna.co.kr/view/AKR2025121907080037...
# 3  https://www.yna.co.kr/view/AKR2025121905740000...
# 4  https://www.yna.co.kr/view/AKR2025121904840000...
#
#                                              article
# 0  [현대차그룹 제공. DB 및 재판매 금지]\n(서울=연합뉴스) 홍규빈 기자 = 현대...
# 1  [연합뉴스 자료사진]\n(서울=연합뉴스) 홍국기 기자 = 국토교통부는 19일 오산 ...
# 2  편집자 주 = 한국국제교류재단(KF)의 지난해 발표에 따르면 세계 한류 팬은 약 2...
